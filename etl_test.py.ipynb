# %%
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

glueContext = GlueContext(SparkContext.getOrCreate())



traffic = glueContext.create_dynamic_frame.from_catalog(
    database = "rt_mcms_db",
    table_name = "campaign"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/qt/kxl9br0s4h34ch733qhqnstm0000gq/T/ipykernel_41052/2343360308.py in <module>
# ----> 1 from awsglue.transforms import *
#       2 from awsglue.utils import getResolvedOptions
#       3 from pyspark.context import SparkContext
#       4 from awsglue.context import GlueContext
#       5 from awsglue.job import Job
#
# ModuleNotFoundError: No module named 'awsglue'
